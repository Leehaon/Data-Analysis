# %% [markdown]
# <a href="https://colab.research.google.com/github/Leehaon/Data-Analysis/blob/main/%ED%95%99%EA%B5%90_%EB%A7%8C%EC%A1%B1%EB%8F%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Koreanize-matplotlib

# %%
import pandas as pd

df = pd.read_csv('학교생활만족도.csv')  # 파일 경로는 상황에 맞게 수정
df.columns = df.columns.str.strip()  # 열 이름 정리
df = df.drop(0, axis=0).reset_index(drop=True)  # 첫 번째 행 삭제
df = df.drop(0, axis=0).reset_index(drop=True)  # 첫 번째 행 삭제

# 중단 사유 열에 의미 있는 이름 부여
column_mapping = {
    '2024': '학교 친구들은 나를 존중하고 배려해준다(전혀 그렇지 않다)',
    '2024.1': '학교 친구들은 나를 존중하고 배려해준다(그렇지 않은 편이다)',
    '2024.2': '학교 친구들은 나를 존중하고 배려해준다(그런 편이다)',
    '2024.3': '학교 친구들은 나를 존중하고 배려해준다(매우 그렇다)',
    '2024.4': '선생님은 학생들을 존중한다(전혀 그렇지 않다)',
    '2024.5': '선생님은 학생들을 존중한다(그렇지 않은 편이다)',
    '2024.6': '선생님은 학생들을 존중한다(그런 편이다)',
    '2024.7': '선생님은 학생들을 존중한다(매우 그렇다)',
    '2024.8': '나는 수업시간이 재밌다(전혀 그렇지 않다)',
    '2024.9': '나는 수업시간이 재밌다(그렇지 않은 편이다)',
    '2024.10': '나는 수업시간이 재밌다(그런 편이다)',
    '2024.11': '나는 수업시간이 재밌다(매우 그렇다)',
    '2024.12': '나는 학교에 가는 것이 즐겁다(전혀 그렇지 않다)',
    '2024.13': '나는 학교에 가는 것이 즐겁다(그렇지 않은 편이다)',
    '2024.14': '나는 학교에 가는 것이 즐겁다(그런 편이다)',
    '2024.15': '나는 학교에 가는 것이 즐겁다(매우 그렇다)'
}

# 열 이름 변경
df = df.rename(columns=column_mapping)

df.head(22)
# Out:
#    응답자유형별(1) 응답자유형별(2) 학교 친구들은 나를 존중하고 배려해준다(전혀 그렇지 않다)  \
# 0         전체        소계                              1.4
# 1         성별        남자                              1.8
# 2         성별        여자                              0.9
# 3       학교급별      초등학교                              1.6
# 4       학교급별       중학교                              1.7
# 5       학교급별      고등학교                              0.9
# 6      고교유형별      일반계고                              0.9
# 7      고교유형별     특성화계고                              0.9
# 8      지역규모별       대도시                              1.2
# 9      지역규모별      중소도시                              1.5
# 10     지역규모별      읍면지역                              1.4
# 11     가족유형별     양부모가정                              1.3
# 12     가족유형별     한부모가정                              1.6
# 13     가족유형별      조손가정                              4.2
# 14     가족유형별        기타                              2.6
# 15     학업성적별         상                              1.2
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# CSV 파일 읽기
df = pd.read_csv('학교생활만족도.csv')
df.columns = df.columns.str.strip()  # 열 이름 정리

# 첫 번째 행 두 번 삭제
df = df.drop(0, axis=0).reset_index(drop=True)
df = df.drop(0, axis=0).reset_index(drop=True)

# 열 이름 매핑
column_mapping = {
    '2024': '학교 친구들은 나를 존중하고 배려해준다(전혀 그렇지 않다)',
    '2024.1': '학교 친구들은 나를 존중하고 배려해준다(그렇지 않은 편이다)',
    '2024.2': '학교 친구들은 나를 존중하고 배려해준다(그런 편이다)',
    '2024.3': '학교 친구들은 나를 존중하고 배려해준다(매우 그렇다)',
    '2024.4': '선생님은 학생들을 존중한다(전혀 그렇지 않다)',
    '2024.5': '선생님은 학생들을 존중한다(그렇지 않은 편이다)',
    '2024.6': '선생님은 학생들을 존중한다(그런 편이다)',
    '2024.7': '선생님은 학생들을 존중한다(매우 그렇다)',
    '2024.8': '나는 수업시간이 재밌다(전혀 그렇지 않다)',
    '2024.9': '나는 수업시간이 재밌다(그렇지 않은 편이다)',
    '2024.10': '나는 수업시간이 재밌다(그런 편이다)',
    '2024.11': '나는 수업시간이 재밌다(매우 그렇다)',
    '2024.12': '나는 학교에 가는 것이 즐겁다(전혀 그렇지 않다)',
    '2024.13': '나는 학교에 가는 것이 즐겁다(그렇지 않은 편이다)',
    '2024.14': '나는 학교에 가는 것이 즐겁다(그런 편이다)',
    '2024.15': '나는 학교에 가는 것이 즐겁다(매우 그렇다)'
}

# 열 이름 변경
df = df.rename(columns=column_mapping)

# 필요있는 열만 추출
respect_columns = [
    '응답자유형별(1)', '응답자유형별(2)',
    '학교 친구들은 나를 존중하고 배려해준다(전혀 그렇지 않다)',
    '학교 친구들은 나를 존중하고 배려해준다(그렇지 않은 편이다)',
    '학교 친구들은 나를 존중하고 배려해준다(그런 편이다)',
    '학교 친구들은 나를 존중하고 배려해준다(매우 그렇다)',
]

respect_df = df[respect_columns]

# 확인
respect_df.head(22)

# 그래프 스타일 설정
sns.set(style="whitegrid")

# 응답 항목만 추출
response_columns = [
    '학교 친구들은 나를 존중하고 배려해준다(전혀 그렇지 않다)',
    '학교 친구들은 나를 존중하고 배려해준다(그렇지 않은 편이다)',
    '학교 친구들은 나를 존중하고 배려해준다(그런 편이다)',
    '학교 친구들은 나를 존중하고 배려해준다(매우 그렇다)',
]

# 숫자로 변환
response_data = respect_df[response_columns].apply(pd.to_numeric, errors='coerce')

# 합계
total_responses = response_data.sum().sum()  # 전체 총합
respect_percentage = response_data.sum() / total_responses * 100  # 비율 계산

# 그래프 스타일 설정
sns.set(style="whitegrid")

# 원그래프 (파이차트) 그리기
plt.figure(figsize=(8, 8))  # 원그래프는 조금 더 정사각형 모양이 좋습니다.

# 파이차트 그리기
plt.pie(respect_percentage, labels=respect_percentage.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Blues_d", len(respect_percentage)))

# 그래프 제목
plt.title("학교 친구들의 존중과 배려에 대한 응답 비율", fontsize=24)

# 한글 폰트 적용
plt.rcParams['font.family'] = 'NanumGothic'  # 한글 폰트 NanumGothic으로 설정

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-6c11d3d97b97>:87: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-11-6c11d3d97b97>:87: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-11-6c11d3d97b97>:87: UserWarning: Glyph 52828 (\N{HANGUL SYLLABLE CIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-11-6c11d3d97b97>:87: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-11-6c11d3d97b97>:87: UserWarning: Glyph 46308 (\N{HANGUL SYLLABLE DEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-11-6c11d3d97b97>:87: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-11-6c11d3d97b97>:87: UserWarning: Glyph 51316 (\N{HANGUL SYLLABLE JON}) missing from font(s) DejaVu Sans.
# ...

# %%
import pandas as pd

# CSV 파일 읽기
df = pd.read_csv('학교생활만족도.csv')
df.columns = df.columns.str.strip()  # 열 이름 정리

# 첫 번째 행 두 번 삭제
df = df.drop(0, axis=0).reset_index(drop=True)
df = df.drop(0, axis=0).reset_index(drop=True)

# 열 이름 매핑
column_mapping = {
    '2024': '학교 친구들은 나를 존중하고 배려해준다(전혀 그렇지 않다)',
    '2024.1': '학교 친구들은 나를 존중하고 배려해준다(그렇지 않은 편이다)',
    '2024.2': '학교 친구들은 나를 존중하고 배려해준다(그런 편이다)',
    '2024.3': '학교 친구들은 나를 존중하고 배려해준다(매우 그렇다)',
    '2024.4': '선생님은 학생들을 존중한다(전혀 그렇지 않다)',
    '2024.5': '선생님은 학생들을 존중한다(그렇지 않은 편이다)',
    '2024.6': '선생님은 학생들을 존중한다(그런 편이다)',
    '2024.7': '선생님은 학생들을 존중한다(매우 그렇다)',
    '2024.8': '나는 수업시간이 재밌다(전혀 그렇지 않다)',
    '2024.9': '나는 수업시간이 재밌다(그렇지 않은 편이다)',
    '2024.10': '나는 수업시간이 재밌다(그런 편이다)',
    '2024.11': '나는 수업시간이 재밌다(매우 그렇다)',
    '2024.12': '나는 학교에 가는 것이 즐겁다(전혀 그렇지 않다)',
    '2024.13': '나는 학교에 가는 것이 즐겁다(그렇지 않은 편이다)',
    '2024.14': '나는 학교에 가는 것이 즐겁다(그런 편이다)',
    '2024.15': '나는 학교에 가는 것이 즐겁다(매우 그렇다)'
}

# 열 이름 변경
df = df.rename(columns=column_mapping)

# 필요있는 열만 추출
respect_columns = [
    '응답자유형별(1)', '응답자유형별(2)',
    '선생님은 학생들을 존중한다(전혀 그렇지 않다)',
    '선생님은 학생들을 존중한다(그렇지 않은 편이다)',
    '선생님은 학생들을 존중한다(그런 편이다)',
    '선생님은 학생들을 존중한다(매우 그렇다)',
]

respect_df = df[respect_columns]

# 확인
respect_df.head(22)

# 그래프 스타일 설정
sns.set(style="whitegrid")

# 응답 항목만 추출
response_columns = [
    '선생님은 학생들을 존중한다(전혀 그렇지 않다)',
    '선생님은 학생들을 존중한다(그렇지 않은 편이다)',
    '선생님은 학생들을 존중한다(그런 편이다)',
    '선생님은 학생들을 존중한다(매우 그렇다)',
]

# 숫자로 변환
response_data = respect_df[response_columns].apply(pd.to_numeric, errors='coerce')

# 합계
total_responses = response_data.sum().sum()  # 전체 총합
respect_percentage = response_data.sum() / total_responses * 100  # 비율 계산

# 그래프 스타일 설정
sns.set(style="whitegrid")

# 원그래프 (파이차트) 그리기
plt.figure(figsize=(8, 8))  # 원그래프는 조금 더 정사각형 모양이 좋습니다.

# 파이차트 그리기
plt.pie(respect_percentage, labels=respect_percentage.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Blues_d", len(respect_percentage)))

# 그래프 제목
plt.title("학교 선생님들의 존중과 배려에 대한 응답 비율", fontsize=24)

# 한글 폰트 적용
plt.rcParams['font.family'] = 'NanumGothic'  # 한글 폰트 NanumGothic으로 설정

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-12-1785aaa3844b>:85: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-12-1785aaa3844b>:85: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-12-1785aaa3844b>:85: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-12-1785aaa3844b>:85: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-12-1785aaa3844b>:85: UserWarning: Glyph 45784 (\N{HANGUL SYLLABLE NIM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-12-1785aaa3844b>:85: UserWarning: Glyph 46308 (\N{HANGUL SYLLABLE DEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
import pandas as pd

# CSV 파일 읽기
df = pd.read_csv('학교생활만족도.csv')
df.columns = df.columns.str.strip()  # 열 이름 정리

# 첫 번째 행 두 번 삭제
df = df.drop(0, axis=0).reset_index(drop=True)
df = df.drop(0, axis=0).reset_index(drop=True)

# 열 이름 매핑
column_mapping = {
    '2024': '학교 친구들은 나를 존중하고 배려해준다(전혀 그렇지 않다)',
    '2024.1': '학교 친구들은 나를 존중하고 배려해준다(그렇지 않은 편이다)',
    '2024.2': '학교 친구들은 나를 존중하고 배려해준다(그런 편이다)',
    '2024.3': '학교 친구들은 나를 존중하고 배려해준다(매우 그렇다)',
    '2024.4': '선생님은 학생들을 존중한다(전혀 그렇지 않다)',
    '2024.5': '선생님은 학생들을 존중한다(그렇지 않은 편이다)',
    '2024.6': '선생님은 학생들을 존중한다(그런 편이다)',
    '2024.7': '선생님은 학생들을 존중한다(매우 그렇다)',
    '2024.8': '나는 수업시간이 재밌다(전혀 그렇지 않다)',
    '2024.9': '나는 수업시간이 재밌다(그렇지 않은 편이다)',
    '2024.10': '나는 수업시간이 재밌다(그런 편이다)',
    '2024.11': '나는 수업시간이 재밌다(매우 그렇다)',
    '2024.12': '나는 학교에 가는 것이 즐겁다(전혀 그렇지 않다)',
    '2024.13': '나는 학교에 가는 것이 즐겁다(그렇지 않은 편이다)',
    '2024.14': '나는 학교에 가는 것이 즐겁다(그런 편이다)',
    '2024.15': '나는 학교에 가는 것이 즐겁다(매우 그렇다)'
}

# 열 이름 변경
df = df.rename(columns=column_mapping)

# 필요있는 열만 추출
respect_columns = [
    '응답자유형별(1)', '응답자유형별(2)',
    '나는 수업시간이 재밌다(전혀 그렇지 않다)',
    '나는 수업시간이 재밌다(그렇지 않은 편이다)',
    '나는 수업시간이 재밌다(그런 편이다)',
    '나는 수업시간이 재밌다(매우 그렇다)',
]

respect_df = df[respect_columns]

# 확인
respect_df.head(22)

# 그래프 스타일 설정
sns.set(style="whitegrid")

# 응답 항목만 추출
response_columns = [
    '나는 수업시간이 재밌다(전혀 그렇지 않다)',
    '나는 수업시간이 재밌다(그렇지 않은 편이다)',
    '나는 수업시간이 재밌다(그런 편이다)',
    '나는 수업시간이 재밌다(매우 그렇다)',
]

# 숫자로 변환
response_data = respect_df[response_columns].apply(pd.to_numeric, errors='coerce')

# 합계
total_responses = response_data.sum().sum()  # 전체 총합
respect_percentage = response_data.sum() / total_responses * 100  # 비율 계산

# 그래프 스타일 설정
sns.set(style="whitegrid")

# 원그래프 (파이차트) 그리기
plt.figure(figsize=(8, 8))  # 원그래프는 조금 더 정사각형 모양이 좋습니다.

# 파이차트 그리기
plt.pie(respect_percentage, labels=respect_percentage.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Blues_d", len(respect_percentage)))

# 그래프 제목
plt.title("수업시간 흥미에 대한 응답 비율", fontsize=24)

# 한글 폰트 적용
plt.rcParams['font.family'] = 'NanumGothic'  # 한글 폰트 NanumGothic으로 설정

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-0f03b886afcc>:85: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-13-0f03b886afcc>:85: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-13-0f03b886afcc>:85: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-13-0f03b886afcc>:85: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-13-0f03b886afcc>:85: UserWarning: Glyph 55141 (\N{HANGUL SYLLABLE HEUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-13-0f03b886afcc>:85: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-13-0f03b886afcc>:85: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from font(s) DejaVu Sans.
# ...

# %%
import pandas as pd

# CSV 파일 읽기
df = pd.read_csv('학교생활만족도.csv')
df.columns = df.columns.str.strip()  # 열 이름 정리

# 첫 번째 행 두 번 삭제
df = df.drop(0, axis=0).reset_index(drop=True)
df = df.drop(0, axis=0).reset_index(drop=True)

# 열 이름 매핑
column_mapping = {
    '2024': '학교 친구들은 나를 존중하고 배려해준다(전혀 그렇지 않다)',
    '2024.1': '학교 친구들은 나를 존중하고 배려해준다(그렇지 않은 편이다)',
    '2024.2': '학교 친구들은 나를 존중하고 배려해준다(그런 편이다)',
    '2024.3': '학교 친구들은 나를 존중하고 배려해준다(매우 그렇다)',
    '2024.4': '선생님은 학생들을 존중한다(전혀 그렇지 않다)',
    '2024.5': '선생님은 학생들을 존중한다(그렇지 않은 편이다)',
    '2024.6': '선생님은 학생들을 존중한다(그런 편이다)',
    '2024.7': '선생님은 학생들을 존중한다(매우 그렇다)',
    '2024.8': '나는 수업시간이 재밌다(전혀 그렇지 않다)',
    '2024.9': '나는 수업시간이 재밌다(그렇지 않은 편이다)',
    '2024.10': '나는 수업시간이 재밌다(그런 편이다)',
    '2024.11': '나는 수업시간이 재밌다(매우 그렇다)',
    '2024.12': '나는 학교에 가는 것이 즐겁다(전혀 그렇지 않다)',
    '2024.13': '나는 학교에 가는 것이 즐겁다(그렇지 않은 편이다)',
    '2024.14': '나는 학교에 가는 것이 즐겁다(그런 편이다)',
    '2024.15': '나는 학교에 가는 것이 즐겁다(매우 그렇다)'
}

# 열 이름 변경
df = df.rename(columns=column_mapping)

# 필요있는 열만 추출
respect_columns = [
    '응답자유형별(1)', '응답자유형별(2)',
    '나는 학교에 가는 것이 즐겁다(전혀 그렇지 않다)',
    '나는 학교에 가는 것이 즐겁다(그렇지 않은 편이다)',
    '나는 학교에 가는 것이 즐겁다(그런 편이다)',
    '나는 학교에 가는 것이 즐겁다(매우 그렇다)',
]

respect_df = df[respect_columns]

# 확인
respect_df.head(22)

# 그래프 스타일 설정
sns.set(style="whitegrid")

# 응답 항목만 추출
response_columns = [
    '나는 학교에 가는 것이 즐겁다(전혀 그렇지 않다)',
    '나는 학교에 가는 것이 즐겁다(그렇지 않은 편이다)',
    '나는 학교에 가는 것이 즐겁다(그런 편이다)',
    '나는 학교에 가는 것이 즐겁다(매우 그렇다)',
]

# 숫자로 변환
response_data = respect_df[response_columns].apply(pd.to_numeric, errors='coerce')

# 합계
total_responses = response_data.sum().sum()  # 전체 총합
respect_percentage = response_data.sum() / total_responses * 100  # 비율 계산

# 그래프 스타일 설정
sns.set(style="whitegrid")

# 원그래프 (파이차트) 그리기
plt.figure(figsize=(8, 8))  # 원그래프는 조금 더 정사각형 모양이 좋습니다.

# 파이차트 그리기
plt.pie(respect_percentage, labels=respect_percentage.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Blues_d", len(respect_percentage)))

# 그래프 제목
plt.title("학교가는 것에 대한 응답 비율", fontsize=24)

# 한글 폰트 적용
plt.rcParams['font.family'] = 'NanumGothic'  # 한글 폰트 NanumGothic으로 설정

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-322c2c5a0567>:85: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-14-322c2c5a0567>:85: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-14-322c2c5a0567>:85: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-14-322c2c5a0567>:85: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-14-322c2c5a0567>:85: UserWarning: Glyph 45784 (\N{HANGUL SYLLABLE NIM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-14-322c2c5a0567>:85: UserWarning: Glyph 46308 (\N{HANGUL SYLLABLE DEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...
